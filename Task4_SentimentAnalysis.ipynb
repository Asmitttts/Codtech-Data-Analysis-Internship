# %%
# Install TextBlob library (required for sentiment analysis)
# !pip install textblob

# %%
# Import required libraries
from textblob import TextBlob   # For sentiment analysis
import pandas as pd             # For handling data

# %%
# Create a sample dataset of reviews (text data)
data = {
    "review": [
        "The food was amazing",
        "Service was very bad",
        "I love this place",
        "Not good experience",
        "Average food",
        "Excellent service and tasty food"
    ]
}

# Convert dictionary into DataFrame
df = pd.DataFrame(data)

# Display dataset
df
# Out:
#                              review
# 0              The food was amazing
# 1              Service was very bad
# 2                 I love this place
# 3               Not good experience
# 4                      Average food
# 5  Excellent service and tasty food

# %%
# Define a function to analyze sentiment of each review
def get_sentiment(text):
    # Create TextBlob object
    analysis = TextBlob(text)

    # Check polarity value
    # Polarity > 0 → Positive
    # Polarity < 0 → Negative
    # Polarity = 0 → Neutral

    if analysis.sentiment.polarity > 0:
        return "Positive"
    elif analysis.sentiment.polarity < 0:
        return "Negative"
    else:
        return "Neutral"

# %%
# Apply sentiment function to each review
df["Sentiment"] = df["review"].apply(get_sentiment)

# Display updated dataset with sentiments
df
# Out:
#                              review Sentiment
# 0              The food was amazing  Positive
# 1              Service was very bad  Negative
# 2                 I love this place  Positive
# 3               Not good experience  Negative
# 4                      Average food  Negative
# 5  Excellent service and tasty food  Positive

# %%
# Count number of Positive, Negative and Neutral reviews
sentiment_count = df["Sentiment"].value_counts()

# Display result
sentiment_count
# Out:
# Sentiment
# Positive    3
# Negative    3
# Name: count, dtype: int64

# %%
# (Optional but good for visualization)

import matplotlib.pyplot as plt

# Plot bar chart of sentiment counts
sentiment_count.plot(kind='bar')

# Add title and labels
plt.title("Sentiment Analysis Result")
plt.xlabel("Sentiment")
plt.ylabel("Count")

# Show plot
plt.show()
